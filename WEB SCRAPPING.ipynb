# %% [markdown]
# # HTML

# %% [markdown]
# ## Tree Structure

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> DIV = Section of Body </b> <br>
# <b> P = Paragraphs </b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Attributes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Scrapy

# %% [markdown]
# ##  XPath

# %% [markdown]
# ### Basics

# %% [markdown]
# - Syntax to navitage through HTML Code

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>SLASHES</b>
# <ul>
#     <li> / = Move through 1 Generaion</li>
#     <li>// = Look forward ALL FUTURE GENEARATIONS</li>
# </ul>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> EXAMPLE: </b>
#  - xpath that directs to the paragraph element containing "Where am I?".

# %% [markdown]
# <html>
#   <body>
#     <div>
#       <p>Good Luck!</p>
#       <p>Not here...</p>
#     </div>
#     <div>
#       <p>Where am I?</p>
#     </div>
#   </body>
# </html>

# %%
xpath = '/html/body/div[2]/p'

# %% [markdown]
# -  XPath string navigating to all paragraph p elements within any HTML code.??

# %%
xpath = '//p'

# %% [markdown]
# <p style="border-radius: 30px;
#           border:2px;
#           border-style:solid;
#           border-color:#000000;
#           padding: 2em;
#           box-shadow: 5px 10px;
#           text-align: justify;
#           background-color:lightgreen;">
# <b>Xpath + Attributes</b>
#
# </p>

# %% [markdown]
# <b> eg: </b>

# %% [markdown]
# <b> '//div[@id="uid"]'. </b> <br>The first part of this string, //div, first looks at all div elements in the HTML document. <br>Then, using the brackets, we specify that we want only the div element with a specific id attribute (in this case uid). To note, the phrase @id="uid" in the brackets would be read as "attribute id equals uid".

# %% [markdown]
# - Assign to the variable xpath an XPath string which will select all span elements whose class attribute equals "span-class":::

# %%
xpath = '//span[@class="span-class"]'

# %% [markdown]
# ###  Brackets & Wildcard

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - the task is to select the paragraph element containing the text "Choose DataCamp!".

# %% [markdown]
# <html>
#   <body>
#     <div>
#       <p>Hello World!</p>
#       <div>
#         <p>Choose DataCamp!</p>
#       </div>
#     </div>
#     <div>
#       <p>Thanks for Watching!</p>
#     </div>
#   </body>
# </html>

# %%
xpath = '/html/body/div[1]/div/p'

# %% [markdown]
# ### Attributes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> EXAMPLES </b> <br>
#  select the paragraph element containing the text "Thanks for Watching!".

# %% [markdown]
# <html>
#   <body>
#     <div id="div1" class="class-1">
#       <p class="class-1 class-2">Hello World!</p>
#       <div id="div2">
#         <p id="p2" class="class-2">Choose DataCamp!</p>
#       </div>
#     </div>
#     <div id="div3" class="class-2">
#       <p class="class-2">Thanks for Watching!</p>
#     </div>
#   </body>
# </html>

# %%
# Create an Xpath string to select desired p element
xpath = '//*[@id="div3"]/p'

# %% [markdown]
# ### Contains

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> Withouth Using Contains </b>

# %% [markdown]
# - select the paragraph element containing the phrase: "Hello World!".

# %% [markdown]
# <html>
#   <body>
#     <div id="div1" class="class-1">
#       <p class="class-1 class-2">Hello World!</p>
#       <div id="div2">
#         <p id="p2" class="class-2">Choose DataCamp!</p>
#       </div>
#     </div>
#     <div id="div3" class="class-2">
#       <p class="class-2">Thanks for Watching!</p>
#     </div>
#   </body>
# </html>

# %%
# Create an XPath string to select p element by class
xpath = '//p[@class="class-1 class-2"]'

# %% [markdown]
# <p style="border-radius: 30px;
#           border:2px;
#           border-style:solid;
#           border-color:#000000;
#           padding: 2em;
#           box-shadow: 5px 10px;
#           text-align: justify;
#           background-color:lightgreen;">
# <b>Example:</b>
#
# </p>

# %% [markdown]
# - xpath which directs to all href attribute values of the hyperlink <b>a </b> elements whose class attributes contain the string "course-block"

# %%
xpath = '//a[contains(@class,"course-block")]/@href'

# %% [markdown]
# ### Accessing Attribute Information

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Select the href attribute value from the DataCamp hyperlink.

# %% [markdown]
# <html>
#   <body>
#     <div id="div1" class="class-1">
#       <p class="class-1 class-2">Hello World!</p>
#       <div id="div2">
#         <p id="p2" class="class-2">Choose
#             <a href="http://datacamp.com">DataCamp!</a>!
#         </p>
#       </div>
#     </div>
#     <div id="div3" class="class-2">
#       <p class="class-2">Thanks for Watching!</p>
#     </div>
#   </body>
# </html>

# %%
xpath = '//p[@id="p2"]/a/@href'

# %% [markdown]
# ## Scrapy Selector

# %% [markdown]
# ### Basics

# %% [markdown]
# - Select and Extract pieces of HTML code

# %%
from scrapy import Selector

# %%
html = '''
<html>
  <body>
    <div class="hello datacamp">
      <p>Hello World</p>
    </div>
      <p>Enjoy DataCamp</p>
  </body>
</html> '''

# %%
#Scrapy Selector Object
sel = Selector(text = html)

# %% [markdown]
# - Selecting all Paragraph Tags:

# %%
sel.xpath("//p")
# Out:
# [<Selector xpath='//p' data='<p>Hello World</p>'>,
#  <Selector xpath='//p' data='<p>Enjoy DataCamp</p>'>]

# %% [markdown]
# - Extract Function:

# %%
sel.xpath("//p").extract()
# Out:
# ['<p>Hello World</p>', '<p>Enjoy DataCamp</p>']

# %% [markdown]
# - Extract Only 1st element in list:

# %%
sel.xpath("//p").extract_first()
# Out:
# '<p>Hello World</p>'

# %% [markdown]
# ### XPath Chaining

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>The only catch is that you need to "glue together" the XPath pieces by using a period at the start of each subsequent XPath string (notice the periods we added to the XPath strings in our examples).</b>
# </ul>
# </div>

# %% [markdown]
# - Use Period at start of chaining

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Getting HTML of a website

# %%
import requests
url = "https://learn.datacamp.com/courses"
html = requests.get(url).content
sel = Selector(text = html)

# %%
url = 'https://assets.datacamp.com/production/repositories/2560/datasets/19a0a26daa8d9db1d920b5d5607c19d6d8094b3b/all_short'

# %%
# Create the Selector object sel from html
sel = Selector( text=html)

# %%
# Print out the number of elements in the HTML document
print( "There are 1020 elements in the HTML document.")
print( "You have found: ", len( sel.xpath('//*') ) )
# Out:
# There are 1020 elements in the HTML document.
# You have found:  461

# %% [markdown]
# ## CSS

# %% [markdown]
# ### Basics

# %% [markdown]
# - Similar to XPath
# - Cascading Style Sheets

# %% [markdown]
# <p style="border-radius: 30px;
#           border:2px;
#           border-style:solid;
#           border-color:#000000;
#           padding: 2em;
#           box-shadow: 5px 10px;
#           text-align: justify;
#           background-color:lightgreen;">
# <b>CSSS vs Xpath:</b>
#
# </p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b> BOTH ARE SAME </b>

# %% [markdown]
# <b> Example - 1 </b>

# %%
# Create the XPath string equivalent to the CSS Locator 
xpath = '/html/body/span[1]//a'

# Create the CSS Locator string equivalent to the XPath
css_locator = 'html>body>span:nth-of-type(1) a'  ##NOTE THE SPACE BEFORE a (SPACE = All generaions)

# %% [markdown]
# <b> Example - 2 </b>

# %%
# Create the XPath string equivalent to the CSS Locator 
xpath = '//div[@id="uid"]/span//h4'

# Create the CSS Locator string equivalent to the XPath
css_locator = 'div#uid > span h4'

# %% [markdown]
# ### Attributes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <p style="border-radius: 30px;
#           border:2px;
#           border-style:solid;
#           border-color:#000000;
#           padding: 2em;
#           box-shadow: 5px 10px;
#           text-align: justify;
#           background-color:lightgreen;">
# <b>Examples:</b>
#
# </p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <p style="border-radius: 30px;
#           border:2px;
#           border-style:solid;
#           border-color:#000000;
#           padding: 2em;
#           box-shadow: 5px 10px;
#           text-align: justify;
#           background-color:lightgreen;">
# <b>Difference b/w Xpath & CSS:</b>
#
# </p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Selectors with CSS

# %%
import requests
from scrapy import Selector

url = "https://learn.datacamp.com/courses"
html = requests.get(url).content
sel = Selector(text = html)

# %% [markdown]
# - CSS Locator string which directs to the hyperlink (a element) children of all div elements belonging to the class "course-block".::

# %%
css_locator = 'div > a'

# %%
css_locator = 'div.course-block > a'

# %%
len(sel.css(css_locator).extract())
# Out:
# 8

# %%
url = "https://www.timeanddate.com/weather/germany/berlin/ext"
html = requests.get(url).content
sel = Selector(text = html)
css_locator = '.h2::text'
weather = sel.css(css_locator).extract_first()
'Weather @ Berlin is : ' + weather[:2] + '  Degree C'
# Out:
# 'Weather @ Berlin is : 30  Degree C'

# %% [markdown]
# ### CSS Wildcard

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Create the CSS Locator to all children of the element whose id is uid
css_locator = '#uid>*'

# %% [markdown]
# ### CSS Attributes and Text Selection

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  - XPath string directing to the text within the paragraph p element with id equal to p3, which does not include the text of future generations of this p element::::

# %%
# Create an XPath string to the desired text.
xpath = '//p[@id="p3"]/text()'

# Create a CSS Locator string to the desired text.
css_locator = 'p#p3::text'

# %% [markdown]
# - XPath string directing to the text within the paragraph p element with id equal to p3, which includes the text of future generations of this p element.::::

# %%
# Create an XPath string to the desired text.
xpath = '//p[@id="p3"]//text()'

# Create a CSS Locator string to the desired text.
css_locator = 'p#p3 ::text'

# %% [markdown]
# ## Response Objects in Scrapy

# %% [markdown]
# - Provides extra tools for multiple website crawling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#from scrapy.http import HtmlResponse

# %%
import scrapy

# %%
scrapy.Request(url='https://www.datacamp.com/courses/all')
# Out:
# <GET https://www.datacamp.com/courses/all>

# %%
from scrapy.http import TextResponse
URL = 'https://www.datacamp.com/courses/all'
response = TextResponse(url=URL)

# %%
# Get the URL to the website loaded in response
this_url = response.url
this_url
# Out:
# 'https://www.datacamp.com/courses/all'

# %%
# Get the title of the website loaded in response
this_title = response.xpath('/html/head/title/text()').extract()

# %%
this_title
# Out:
# []

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Selector vs Response Object:</b>
# </ul>
# </div>

# %% [markdown]
# - Something that we should emphasize at this point about the relationship between a Selector and Response objects is that both objects return a SelectorList when using the xpath or css methods to direct to elements. In this exercise, we'll prove it to you, by having you find all hyperlink elements belonging to the class course-block__link (notice the double underscore!) and looking at the object that is produced when doing so.

# %%
import requests
url = 'https://www.datacamp.com/courses/all'
html = requests.get(url).content
sel = Selector(text = html)

# %%
# Create a CSS Locator string to the desired hyperlink elements
css_locator = 'a.course-block__link'

# %%
# Select the hyperlink elements from response and sel
response_as = response.css(css_locator)
sel_as = sel.css(css_locator)

# %%
len(response_as)
# Out:
# 0

# %%
len(sel_as)
# Out:
# 335

# %%
# Examine similarity
nr = len(response_as)
ns = len(sel_as)
for i in range( min(nr, ns, 2) ):
    print( "Element %d from response: %s" % (i+1, response_as[i]) )
    print( "Element %d from sel: %s" % (i+1, sel_as[i]) )
    print( "" )

# %% [markdown]
# ## Mini-Project

# %%
import scrapy

# %%
from scrapy.http import TextResponse
URL = 'https://www.datacamp.com/courses/all'
response = TextResponse(url=URL)

# %%
type(response)
# Out:
# scrapy.http.response.text.TextResponse

# %% [markdown]
# - The course titles are the text from all the h4 elements within the HTML document.

# %%
# Create a SelectorList of the course titles
crs_title_els = response.css('h4::text')

# Extract the course titles 
crs_titles = crs_title_els.extract()
crs_titles
# Out:
# []

# %% [markdown]
# ## Spiders

# %% [markdown]
# ### Basic Structure

# %%
import scrapy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <p style="border-radius: 30px;
#           border:2px;
#           border-style:solid;
#           border-color:#000000;
#           padding: 2em;
#           box-shadow: 5px 10px;
#           text-align: justify;
#           background-color:lightgreen;">
# <b>General Structure</b>
#
# </p>

# %%
# Create the spider class
class YourSpider(scrapy.Spider):
    name = "your_spider"
  # start_requests method
    def start_requests(self):
        pass
  # parse method
    def parse(self, response):
        pass

# %% [markdown]
# <b> SIMPLE EXAMPLE </b>

# %%
# Create the spider class
class YourSpider( scrapy.Spider ):
    name = "your_spider"
  # start_requests method
    def start_requests( self ):
        urls = ["https://www.datacamp.com", 
                "https://scrapy.org"]
        for url in urls:
            yield url
  # parse method
    def parse( self, response ):
        pass

# %% [markdown]
# ### Start Requests

# %%
# Create the spider class
class YourSpider( scrapy.Spider ):
    name = "your_spider"
  # start_requests method
    def start_requests( self ):
        yield scrapy.Request( url = "https://www.datacamp.com", callback = self.parse ) #parse method
  # parse method
    def parse( self, response ):
        pass

# %% [markdown]
# ### Simple Example - 1

# %% [markdown]
# - Saving Links in a websiter to a file:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Simple Example - 2

# %% [markdown]
# -  retrieve the author names from a shortened version of the DataCamp course directory.

# %%
url_short = 'https://assets.datacamp.com/production/repositories/2560/datasets/19a0a26daa8d9db1d920b5d5607c19d6d8094b3b/all_short'

# %% [markdown]
# - Your job will be to create the list of extracted author names in the parse method of the spider.:

# %%
# Import the scrapy library
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
# Create the Spider class
class DCspider( scrapy.Spider ):
    name = 'dcspider'
  # start_requests method
    def start_requests( self ):
        yield scrapy.Request( url = url_short, callback = self.parse )
  # parse method
    def parse( self, response ):
    # Create an extracted list of course author names
        author_names = response.css( 'p.course-block__author-name::text' ).extract()
    # Here we will just return the list of Authors
        return author_names

# %% [markdown]
# ### Simple Example - 3  (Crawling b/w sites)

# %% [markdown]
# -  This spider starts at the shortened DataCamp course directory, then extracts the links of the courses in the parse method; from there, it will follow those links to extract the course descriptions from each course page in the parse_descr method, and put these descriptions into the list course_descrs

# %%
url_short = 'https://assets.datacamp.com/production/repositories/2560/datasets/19a0a26daa8d9db1d920b5d5607c19d6d8094b3b/all_short'

# %%
# Create the Spider class
class DCdescr( scrapy.Spider ):
    name = 'dcdescr'
    
  # start_requests method
    def start_requests( self ):
        yield scrapy.Request( url = url_short, callback = self.parse )
        
  # First parse method
    def parse( self, response ):
        links = response.css( 'div.course-block > a::attr(href)' ).extract()
    # Follow each of the extracted links
        for link in links:
            yield response.follow( url = link, callback = self.parse_descr )

# Second parsing method
    def parse_descr( self, response ):
    # Extract course description
        course_descr = response.css( 'p.course__description::text' ).extract_first()
    # For now, just yield the course description
        yield course_descr

# %% [markdown]
# ### Capstone Project - 1

# %% [markdown]
# #### Part - 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -  creating an entire web-crawler to access course information from each course in the DataCamp course directory.

# %%
# Import scrapy
import scrapy
# Import the CrawlerProcess: for running the spider
from scrapy.crawler import CrawlerProcess

# %%
url_short = 'https://assets.datacamp.com/production/repositories/2560/datasets/19a0a26daa8d9db1d920b5d5607c19d6d8094b3b/all_short'

# %%
# Create the Spider class
class DC_Chapter_Spider(scrapy.Spider):
    name = "dc_chapter_spider"
  # start_requests method
    def start_requests(self):
        yield scrapy.Request(url = url_short,
                         callback = self.parse_front)
  # First parsing method
    def parse_front(self, response):
        course_blocks = response.css('div.course-block')
        course_links = course_blocks.xpath('./a/@href')
        links_to_follow = course_links.extract()
        for url in links_to_follow:
            yield response.follow(url = url,
                            callback = self.parse_pages) #sent to next function
  # Second parsing method
    def parse_pages(self, response):
        crs_title = response.xpath('//h1[contains(@class,"title")]/text()')
        crs_title_ext = crs_title.extract_first().strip()
        ch_titles = response.css('h4.chapter__title::text')
        ch_titles_ext = [t.strip() for t in ch_titles.extract()]
        dc_dict[ crs_title_ext ] = ch_titles_ext

# %%
# Initialize the dictionary **outside** of the Spider class
dc_dict = dict()

# %%
# Run the Spider
process = CrawlerProcess()
process.crawl(DC_Chapter_Spider)
process.start()
# Out:
# 2020-08-20 20:04:19 [scrapy.utils.log] INFO: Scrapy 2.3.0 started (bot: scrapybot)
# 2020-08-20 20:04:19 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.8, Platform Windows-10-10.0.18362-SP0
# 2020-08-20 20:04:19 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-08-20 20:04:19 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-08-20 20:04:19 [scrapy.extensions.telnet] INFO: Telnet Password: 2b24bd43b3f16dba
# 2020-08-20 20:04:19 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-08-20 20:04:20 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ...

# %%
dc_dict
# Out:
# {'Intermediate R': ['Conditionals and Control Flow',
#   'Functions',
#   'Utilities',
#   'Loops',
#   'The apply family',
#   'Conditionals and Control Flow',
#   'Loops',
#   'Functions',
#   'The apply family',
#   'Utilities'],
#  'Introduction to R': ['Intro to basics',
#   'Vectors',
#   'Matrices',
#   'Factors',
#   'Data frames',
#   'Lists'],
#  'Intro to Python for Data Science': ['Python Basics',
#   'Functions and Packages',
#   'Python Lists',
#   'NumPy',
#   'Python Basics',
#   'Python Lists',
#   'Functions and Packages',
#   'NumPy'],
#  'Introduction to Machine Learning': ['What is Machine Learning',
#   'Classification',
#   'Clustering',
#   'Performance measures',
#   'Regression',
#   'What is Machine Learning',
#   'Performance measures',
#   'Classification',
#   'Regression',
#   'Clustering'],
#  'Data Manipulation in R with dplyr': ['Introduction to dplyr and tbls',
#   'Filter and arrange',
#   'Group_by and working with databases',
# ...

# %% [markdown]
# #### Part - 2

# %% [markdown]
# - In this exercise, you are asked to create a CSS Locator string direct to the text of the course description. All you need to know is that from the course page, the course description text is within a paragraph p element which belongs to the class course__description

# %%
# Import scrapy
import scrapy
# Import the CrawlerProcess: for running the spider
from scrapy.crawler import CrawlerProcess

# %%
url_short = 'https://assets.datacamp.com/production/repositories/2560/datasets/19a0a26daa8d9db1d920b5d5607c19d6d8094b3b/all_short'

# %%
# Create the Spider class
class DC_Description_Spider(scrapy.Spider):
    name = "dc_chapter_spider"
  # start_requests method
    def start_requests(self):
        yield scrapy.Request(url = url_short,
                         callback = self.parse_front)
  # First parsing method
    def parse_front(self, response):
        course_blocks = response.css('div.course-block')
        course_links = course_blocks.xpath('./a/@href')
        links_to_follow = course_links.extract()
        for url in links_to_follow:
            yield response.follow(url = url,
                            callback = self.parse_pages)
  # Second parsing method
    def parse_pages(self, response):
    # Create a SelectorList of the course titles text
        crs_title = response.xpath('//h1[contains(@class,"title")]/text()')
    # Extract the text and strip it clean
        crs_title_ext = crs_title.extract_first().strip()
    # Create a SelectorList of course descriptions text
        crs_descr = response.css('p.course__description::text')
    # Extract the text and strip it clean
        crs_descr_ext = crs_descr.extract_first().strip()
    # Fill in the dictionary
        dc_dict[crs_title_ext] = crs_descr_ext

# %%
# Initialize the dictionary **outside** of the Spider class
dc_dict = dict()

# %%
# Run the Spider
process = CrawlerProcess()
process.crawl(DC_Description_Spider)
process.start()
# Out:
# 2020-08-20 20:14:34 [scrapy.utils.log] INFO: Scrapy 2.3.0 started (bot: scrapybot)
# 2020-08-20 20:14:34 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.8, Platform Windows-10-10.0.18362-SP0
# 2020-08-20 20:14:34 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-08-20 20:14:34 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-08-20 20:14:34 [scrapy.extensions.telnet] INFO: Telnet Password: 1edfb5068181027d
# 2020-08-20 20:14:34 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-08-20 20:14:35 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ...

# %%
dc_dict
# Out:
# {'Introduction to R': 'In this introduction to R, you will master the basics of this beautiful open source language, including factors, lists and data frames. With the knowledge gained in this course, you will be ready to undertake your first very own data analysis. With over 2 million users worldwide R is rapidly becoming the leading programming language in statistics and data science. Every year, the number of R users grows by 40% and an increasing number of organizations are using it in their day-to-day activities. Leverage the power of R by completing this free R online course today!',
#  'Data Visualization in R with ggvis': 'Learn to create interactive graphs to display distributions, relationships, model fits, and more using ggvis.',
#  'Intermediate R - Practice': 'This follow-up course on Intermediate R does not cover new programming concepts. Instead, you will strengthen your knowledge of the topics in Intermediate R with a bunch of new and fun exercises.',
# ...

# %% [markdown]
# #### Part - 3

# %% [markdown]
# On the course directory page of DataCamp, each listed course has a title and a short course description. This spider will be used to scrape the course directory to extract the course titles and short course descriptions. You will not need to follow any links this time. Everything you need to know is:
# <br><br>
# The course titles are defined by the text within an h4 element whose class contains the string block__title (double underline).<br><br>
# The short course descriptions are defined by the text within a paragraph p element whose class contains the string block__description (double underline).

# %%
url_short = 'https://assets.datacamp.com/production/repositories/2560/datasets/19a0a26daa8d9db1d920b5d5607c19d6d8094b3b/all_short'

# %%
# Import scrapy
import scrapy
# Import the CrawlerProcess
from scrapy.crawler import CrawlerProcess

# %%
# Create the Spider class
class YourSpider(scrapy.Spider):
    name = 'yourspider'
  # start_requests method
    def start_requests(self):
        yield scrapy.Request(url = url_short, callback = self.parse)
    def parse(self, response):
    # My version of the parser you wrote in the previous part
        crs_titles = response.xpath('//h4[contains(@class,"block__title")]/text()').extract()
        crs_descrs = response.xpath('//p[contains(@class,"block__description")]/text()').extract()
        for crs_title, crs_descr in zip(crs_titles, crs_descrs):
            dc_dict[crs_title] = crs_descr

# %%
# Initialize the dictionary **outside** of the Spider class
dc_dict = dict()

# %%
# Run the Spider
process = CrawlerProcess()
process.crawl(YourSpider)
process.start()
# Out:
# 2020-08-20 20:19:12 [scrapy.utils.log] INFO: Scrapy 2.3.0 started (bot: scrapybot)
# 2020-08-20 20:19:12 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.8, Platform Windows-10-10.0.18362-SP0
# 2020-08-20 20:19:12 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-08-20 20:19:12 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-08-20 20:19:12 [scrapy.extensions.telnet] INFO: Telnet Password: f9ebcb12c7c90da8
# 2020-08-20 20:19:12 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-08-20 20:19:13 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ...

# %%
dc_dict
# Out:
# {'Introduction to R': '\n          Master the basics of data analysis by manipulating common data structures such as vectors, matrices and data frames.\n        ',
#  'Data Analysis in R, the data.table Way': '\n          Master core concepts in data manipulation such as subsetting, updating, indexing and joining your data using data.table.\n        ',
#  'Data Manipulation in R with dplyr': '\n          Master techniques for data manipulation using the select, mutate, filter, arrange, and summarise functions in dplyr.\n        ',
#  'Data Visualization in R with ggvis': '\n          Learn to create interactive graphs to display distributions, relationships, model fits, and more using ggvis.\n        ',
#  'Reporting with R Markdown': '\n          Learn to create interactive analyses and automated reports with R Markdown.\n        ',
# ...

# %% [markdown]
# # BeautiFul Soup

# %%
from bs4 import BeautifulSoup as BS
import requests
import urllib.request

# %%
response = urllib.request.urlopen("https://coreyms.com/")
html = response.read()

# %%
soup = BS(html , 'lxml')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <!-- This site is optimized with the Yoast SEO plugin v14.8 - https://yoast.com/wordpress/plugins/seo/ -->\n  <title>\n   CoreyMS - Development, Design, DIY, and more\n  </title>\n  <meta content="Development, Design, DIY, and more" name="description"/>\n  <meta content="index, follow" name="robots"/>\n  <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="googlebot"/>\n  <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="bingbot"/>\n  <link href="https://coreyms.com/" rel="canonical"/>\n  <link href="https://coreyms.com/page/2" rel="next"/>\n  <meta content="en_US" property="og:locale"/>\n  <meta content="website" property="og:type"/>\n  <meta content="CoreyMS - Development, Design, DIY, and more" property="og:title"/>\n  <meta content="Develo
# ...

# %%
match = soup.title
print(match)
# Out:
# <title>CoreyMS - Development, Design, DIY, and more</title>

# %%
match = soup.title.text
print(match)
# Out:
# CoreyMS - Development, Design, DIY, and more

# %%
match = soup.div.text
print(match)  #Prints onlny first div
# Out:
#
#
#
#
#
#
#
#
#
#
#
# CoreyMSDevelopment, Design, DIY, and more
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contact
# Portfolio
#
# Development
#
# Python
# Git
# Terminal
# JavaScript
# WordPress
#
#
# Design
#
# CSS
#
#
# DIY
#
# Woodworking
# Home Improvement
#
#
# Contributors
# Support
# Giveaway
# Python Tutorial: Zip Files – Creating and Extracting Zip Archives
# November 19, 2019 by Corey Schafer Leave a Comment
# In this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…
#
# Filed Under: Development, Python Tagged With: gzip, shutil, zip, zipfilePython Data Science Tutorial: Analyzing the 2019 Stack Overflow Developer Survey
# ...

# %%
FIND METHOD

# %%
match = soup.find('div')
print(match)
# Out:
# <div class="site-container"><header class="site-header" itemscope="" itemtype="https://schema.org/WPHeader"><div class="wrap"><div class="title-area"> <div class="site-avatar">
# <a href="https://coreyms.com/"><svg class="site-avatar-svg" enable-background="new 0 0 441.5 441.5" height="150px" id="Layer_1" version="1.1" viewbox="0 0 441.5 441.5" width="150px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g class="site-avatar-background">
# <path d="M79.178 390.133C30.781 349.639 0 288.789 0 220.75C0 98.833 98.833 0 220.75 0S441.5 98.833 441.5 220.75 c0 63.558-26.86 120.842-69.848 161.12" fill="#56616B"></path>
# </g>
# <g class="site-avatar-foreground">
# ...

# %% [markdown]
# Accessing USing Atrribute of tag's::::::::

# %%
match = soup.find('div'  ,class_ = "site-container")
print(match)
# Out:
# <div class="site-container"><header class="site-header" itemscope="" itemtype="https://schema.org/WPHeader"><div class="wrap"><div class="title-area"> <div class="site-avatar">
# <a href="https://coreyms.com/"><svg class="site-avatar-svg" enable-background="new 0 0 441.5 441.5" height="150px" id="Layer_1" version="1.1" viewbox="0 0 441.5 441.5" width="150px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g class="site-avatar-background">
# <path d="M79.178 390.133C30.781 349.639 0 288.789 0 220.75C0 98.833 98.833 0 220.75 0S441.5 98.833 441.5 220.75 c0 63.558-26.86 120.842-69.848 161.12" fill="#56616B"></path>
# </g>
# <g class="site-avatar-foreground">
# ...

# %%
ACESSING CHILDREN TAGS

# %%
children = match.h1.a
children
# Out:
# <a href="https://coreyms.com/">CoreyMS</a>

# %%
children = match.h1.text
children
# Out:
# 'CoreyMS'

# %%
FIND ALL METHOD::

# %%
find return only the first matched tag
find_all returens all matches tags
